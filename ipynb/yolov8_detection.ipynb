# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ROOT_DIR = '/content/drive/MyDrive/yolov8'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 12.8 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO

model = YOLO("yolov8n.yaml") # build a new model from scratch

results = model.train(data=os.path.join(ROOT_DIR, "config.yaml"), epochs=125 )    # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
import shutil

source_path = '/content/runs'
destination_path = '/content/drive/MyDrive/yolov8/runs'

shutil.copytree(source_path, destination_path)
# Out:
# '/content/drive/MyDrive/yolov8/runs'

# %%
#import locale

#locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !ls /content/runs/detect/train
# Out:
# args.yaml					   R_curve.png		val_batch0_labels.jpg
# confusion_matrix_normalized.png			   results.csv		val_batch0_pred.jpg
# confusion_matrix.png				   results.png		val_batch1_labels.jpg
# events.out.tfevents.1697647993.1d7e818e77ca.284.0  train_batch0.jpg	val_batch1_pred.jpg
# F1_curve.png					   train_batch1.jpg	val_batch2_labels.jpg
# labels_correlogram.jpg				   train_batch2.jpg	val_batch2_pred.jpg
# labels.jpg					   train_batch7360.jpg	weights
# P_curve.png					   train_batch7361.jpg
# PR_curve.png					   train_batch7362.jpg

# %%
from ultralytics import YOLO

from IPython.display import display, Image


# %cd /content
Image(filename=f'/content/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd /content
Image(filename=f'/content/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
Image(filename=f'/content/runs/detect/train/val_batch0_pred.jpg', width=600)

# %%
metrics = model.val()   # evaluate model performance on the validation set

#!yolo task=detect mode=val model=/content/drive/MyDrive/yolov8/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/yolov8/config.yaml
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/yolov8/data/valid/labels.cache... 289 images, 0 backgrounds, 0 corrupt: 100%|██████████| 289/289 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
#                    all        289        514      0.864      0.729       0.81      0.536
#                  crack        289        178       0.93       0.82      0.893      0.628
#                pothole        289        336      0.798      0.637      0.727      0.444
# Speed: 1.8ms preprocess, 5.3ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to runs/detect/train2

# %%
print(metrics)
# Out:
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7c518769e7d0>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
# ...

# %%
# Assuming you have loaded your model as 'model'
from ultralytics import YOLO

model = YOLO("yolov8n.yaml")
model.load("/content/runs/detect/train/weights/best.pt")
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# %cd /content/
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source={ROOT_DIR}/data/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/147 /content/drive/MyDrive/yolov8/data/test/images/00010_jpg.rf.d8bb51f65d0bbaaf9dbebcd1a1f2ed2a.jpg: 640x640 1 crack, 7.5ms
# image 2/147 /content/drive/MyDrive/yolov8/data/test/images/00030_jpg.rf.16ecab143ac829c6bc210ff1c181b589.jpg: 640x640 1 crack, 21.3ms
# image 3/147 /content/drive/MyDrive/yolov8/data/test/images/00031_jpg.rf.a90552d8213c7c75d013cd860099a82b.jpg: 640x640 1 crack, 7.7ms
# image 4/147 /content/drive/MyDrive/yolov8/data/test/images/00033_jpg.rf.abf3e7285e64089d32376829a1fdf083.jpg: 640x640 1 crack, 7.3ms
# image 5/147 /content/drive/MyDrive/yolov8/data/test/images/00147_jpg.rf.d176e1df82ad616686d544b052c98a67.jpg: 640x640 1 crack, 7.3ms
# image 6/147 /content/drive/MyDrive/yolov8/data/test/images/00148_jpg.rf.0a202d87a8667db81cccb0ca11c15d36.jpg: 640x640 1 crack, 7.3ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[101:106]:
      display(Image(filename=image_path, width=300))
      print("\n")

# %%
path = model.export(format="onnx")
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.00GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.yaml' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (0.0 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 206.0 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.8s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.14.1 opset 17...
# ONNX: export success ✅ 9.7s, saved as 'yolov8n.onnx' (12.2 MB)
#
# Export complete (11.4s)
# Results saved to /content
# Predict:         yolo predict task=detect model=yolov8n.onnx imgsz=640
# Validate:        yolo val task=detect model=yolov8n.onnx imgsz=640 data=None
# ...
